# %%
import cv2
from matplotlib import pyplot as plt
img=cv2.imread('test_images/0 (239).jpg',0)
print(img.shape)
height,width=img.shape
plt.imshow(img,cmap='gray')
# Out:
# (512, 512)

# %%
imgFlattern=img.reshape(height*width,1)
print(imgFlattern.shape)
# Out:
# (262144, 1)

# %%
from sklearn.cluster import KMeans

model=KMeans(n_clusters=6)
model.fit(imgFlattern)
labels=model.labels_
print(labels.shape)
labels2D=labels.reshape(height,width)
# Out:
# (262144,)

# %%
print(img[200:210,200:210])
print('______________________________________________________________')
print(labels2D[200:210,200:210])
# Out:
# [[44 44 43 42 42 42 43 43 44 44]
#  [44 44 44 44 45 45 45 45 45 45]
#  [44 45 46 47 47 48 47 47 46 46]
#  [42 43 45 47 48 48 48 47 47 47]
#  [41 42 43 44 45 46 46 46 47 47]
#  [42 42 41 41 42 43 45 45 47 47]
#  [45 43 41 39 40 41 44 46 46 46]
#  [48 45 41 39 39 41 44 46 46 46]
#  [66 51 38 36 38 38 39 44 46 46]
#  [75 61 47 40 37 35 36 41 45 45]]
# ______________________________________________________________
# [[4 4 4 4 4 4 4 4 4 4]
#  [4 4 4 4 4 4 4 4 4 4]
#  [4 4 4 4 4 4 4 4 4 4]
#  [4 4 4 4 4 4 4 4 4 4]
#  [4 4 4 4 4 4 4 4 4 4]
#  [4 4 4 4 4 4 4 4 4 4]
#  [4 4 4 4 4 4 4 4 4 4]
#  [4 4 4 4 4 4 4 4 4 4]
#  [1 1 4 4 4 4 4 4 4 4]
#  [3 1 4 4 4 4 4 4 4 4]]

# %%
plt.imshow(labels2D)
plt.colorbar()
plt.show()

# %%
import joblib
joblib.dump(model,'brain_ttumor_KMeans_model.sav')
# Out:
# ['brain_ttumor_KMeans_model.sav']
